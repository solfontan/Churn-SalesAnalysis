# %% [markdown]
# ### Importamos variables

# %%
import sys
import os

# Obtener la ruta del directorio raíz (un nivel arriba)
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..'))) 

### Manipulación de Datos
import pandas as pd
import numpy as np

### Visualización de Datos
import seaborn as sns
import matplotlib.pyplot as plt

### Tratamiento de datos
from utils.funciones import CategoricalAnalysis, extended_describe

# %% [markdown]
# ### Importamos datos

# %%
df = pd.read_csv(r"..\data\raw\Location_Data.csv")
df.head()
# Out:
#   customer_id        country       state          city  zip_code  \
# 0  0002-ORFBO  United States  California  Frazier Park     93225
# 1  0003-MKNFE  United States  California      Glendale     91206
# 2  0004-TLHLJ  United States  California    Costa Mesa     92627
# 3  0011-IGKFF  United States  California      Martinez     94553
# 4  0013-EXCHZ  United States  California     Camarillo     93010
#
#    total_population   latitude   longitude
# 0              4498  34.827662 -118.999073
# 1             31297  34.162515 -118.203869
# 2             62069  33.645672 -117.922613
# 3             46677  38.014457 -122.115432
# 4             42853  34.227846 -119.079903

# %% [markdown]
# |Column Name |	Description|
# |--------------|----------|
# |CustomerID	| A unique ID that identifies each customer.|
# |Country|	The country of the customer’s primary residence.|
# |State|	The state of the customer’s primary residence.|
# |City|	The city of the customer’s primary residence.|
# |Zip Code|	The zip code of the customer’s primary residence.|
# |Total Population|	A current population estimate for the entire Zip Code area.|
# |Latitude|	The latitude of the customer’s primary residence.|
# |Longitude|	The longitude of the customer’s primary residence.|

# %%
print(f'La base de datos a analizar posee {df.shape[0]} filas y {df.shape[1]} columnas')
print(f'\nLas features que tenemos son: {list(df.columns)}')
# Out:
# La base de datos a analizar posee 7043 filas y 8 columnas
#
# Las features que tenemos son: ['customer_id', 'country', 'state', 'city', 'zip_code', 'total_population', 'latitude', 'longitude']

# %% [markdown]
# ### Primera exploración

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       7043 non-null   object
#  1   country           7043 non-null   object
#  2   state             7043 non-null   object
#  3   city              7043 non-null   object
#  4   zip_code          7043 non-null   int64
#  5   total_population  7043 non-null   int64
#  6   latitude          7043 non-null   float64
#  7   longitude         7043 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 440.3+ KB

# %%
df.describe()
# Out:
#            zip_code  total_population     latitude    longitude
# count   7043.000000       7043.000000  7043.000000  7043.000000
# mean   93486.071134      22139.814568    36.197455  -119.756684
# std     1856.768045      21152.174407     2.468929     2.154425
# min    90001.000000         11.000000    32.555828  -124.301372
# 25%    92101.000000       2344.000000    33.990646  -121.788090
# 50%    93518.000000      17554.000000    36.205465  -119.595293
# 75%    95329.000000      36125.000000    38.161321  -117.969795
# max    96150.000000     105285.000000    41.962127  -114.192901

# %%
df.describe(include="object")
# Out:
#        customer_id        country       state         city
# count         7043           7043        7043         7043
# unique        7043              1           1         1106
# top     9995-HOTOH  United States  California  Los Angeles
# freq             1           7043        7043          293

# %% [markdown]
# - Lo único diferente es la ciudad pero todos encuentra dentro de california en USA.

# %%
df.isna().sum()
# Out:
# customer_id         0
# country             0
# state               0
# city                0
# zip_code            0
# total_population    0
# latitude            0
# longitude           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, country, state, city, zip_code, total_population, latitude, longitude]
# Index: []

# %% [markdown]
# - Poseemos un dataset sin valores nulos.
# - Todos nuestros usuarios son de Estados Unidos del estado de California.
# - Al tener un customer_id unico para cada, no poseemos duplicados

# %%
sns.pairplot(df)
plt.show()

# %%
df[df['country'] != 'United States']
# Out:
# Empty DataFrame
# Columns: [customer_id, country, state, city, zip_code, total_population, latitude, longitude]
# Index: []

# %%
df[df['state'] != 'California']
# Out:
# Empty DataFrame
# Columns: [customer_id, country, state, city, zip_code, total_population, latitude, longitude]
# Index: []

# %% [markdown]
# - Al no poseer otra variable a nivel geográfico carece de sentido poseer las columnas 'country' y 'state' ya qu eestas solo poseen una variable y su ubicación la obtenemos mayormente de las columnas 'latitud' y 'longitud'

# %%
df = df.drop(columns=['state','country'])

# %%
df.to_csv(path_or_buf=r'..\data\clean\location_data_clean.csv',index=False)

# %% [markdown]
# ### Análisis exploratorio

# %% [markdown]
# #### Análisis univariante

# %%
df = pd.read_csv(r"..\data\clean\location_data_clean.csv")
df.head()
# Out:
#   customer_id          city  zip_code  total_population   latitude   longitude
# 0  0002-ORFBO  Frazier Park     93225              4498  34.827662 -118.999073
# 1  0003-MKNFE      Glendale     91206             31297  34.162515 -118.203869
# 2  0004-TLHLJ    Costa Mesa     92627             62069  33.645672 -117.922613
# 3  0011-IGKFF      Martinez     94553             46677  38.014457 -122.115432
# 4  0013-EXCHZ     Camarillo     93010             42853  34.227846 -119.079903

# %%
categorical_analyzer = CategoricalAnalysis(df=df)
categorical_analyzer.plot_top_categories(title='Ciudades', labely='Ciudades', column_name='city')

# %% [markdown]
# - Abarcando el 32,5% nuestros usuarios provienen de la ciudad de Los Ángeles siguiendo por San diego con un 31,6%

# %%
categorical_analyzer.plot_distribution(title= 'Población total', column_name='total_population', cant_bins = 40, color='crimson', rotation=0, alpha=0.9)
# Out:
# La distribución es leptocúrtica con una curtosis de 0.32. Los datos se encuentran concentrados alrededor de la media.
# La distribución se encuentra sesgada hacia la izquierda 0.91.
#                    count          mean   median   mode       std   min  \
# total_population  7043.0  22139.814568  17554.0  42239  21152.17  11.0
#
#                      25%      50%      75%       max  kurtosis  skewness
# total_population  2344.0  17554.0  36125.0  105285.0      0.32      0.91

# %%
df[df['total_population'] == 11]
# Out:
#      customer_id    city  zip_code  total_population   latitude   longitude
# 1380  2040-XBAVJ  Malibu     90263                11  34.037037 -118.705803
# 2467  3530-CRZSB  Malibu     90263                11  34.037037 -118.705803
# 3308  4713-LZDRV  Malibu     90263                11  34.037037 -118.705803
# 5893  8292-FRFZQ  Malibu     90263                11  34.037037 -118.705803
# 6989  9919-YLNNG  Malibu     90263                11  34.037037 -118.705803

# %%
df[df['city'] == 'Malibu']
# Out:
#      customer_id    city  zip_code  total_population   latitude   longitude
# 202   0318-ZOPWS  Malibu     90265             19630  34.074572 -118.831181
# 1380  2040-XBAVJ  Malibu     90263                11  34.037037 -118.705803
# 2467  3530-CRZSB  Malibu     90263                11  34.037037 -118.705803
# 3308  4713-LZDRV  Malibu     90263                11  34.037037 -118.705803
# 5346  7551-JOHTI  Malibu     90265             19630  34.074572 -118.831181
# 5893  8292-FRFZQ  Malibu     90263                11  34.037037 -118.705803
# 6016  8498-XXGWA  Malibu     90265             19630  34.074572 -118.831181
# 6061  8591-NXRCV  Malibu     90265             19630  34.074572 -118.831181
# 6982  9909-IDLEK  Malibu     90265             19630  34.074572 -118.831181
# 6989  9919-YLNNG  Malibu     90263                11  34.037037 -118.705803

# %%
# %pip install folium
import folium

# Crear un mapa centrado en las coordenadas de California
mapa = folium.Map(location=[34.037037, -118.705803], zoom_start=13)

# Añadir marcadores para los registros problemáticos
for _, row in df[df['city'] == 'Malibu'].iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=f"Customer ID: {row['customer_id']}").add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_000023041d23263c6d2d5e3bc38fad39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_000023041d23263c6d2d5e3bc38fad39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_000023041d23263c6d2d5e3bc38fad39 = L.map(
#                 &quot;map_000023041d23263c6d2d5e3bc38fad39&quot;,
#                 {
#                     center: [34.037037, -118.705803],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3032a152dbee61db97979be2c3627946 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3032a152dbee61db97979be2c3627946.addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#             var marker_66f3155f92792da4b19ba83bac386616 = L.marker(
#                 [34.074572, -118.831181],
#                 {
# }
#             ).addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#         var popup_57c7b52d3015fa39eba64383f75eebc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f32ba957096e92fadb5cba922b534b31 = $(`&lt;div id=&quot;html_f32ba957096e92fadb5cba922b534b31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 0318-ZOPWS&lt;/div&gt;`)[0];
#                 popup_57c7b52d3015fa39eba64383f75eebc1.setContent(html_f32ba957096e92fadb5cba922b534b31);
#
#
#
#         marker_66f3155f92792da4b19ba83bac386616.bindPopup(popup_57c7b52d3015fa39eba64383f75eebc1)
#         ;
#
#
#
#
#             var marker_7c36a783770bde499a7cc21e2dbabbb6 = L.marker(
#                 [34.037037, -118.705803],
#                 {
# }
#             ).addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#         var popup_6314278178ff9218381bb50b60b0d729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0026b7adda082138cf9e62e4114a2f3 = $(`&lt;div id=&quot;html_b0026b7adda082138cf9e62e4114a2f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 2040-XBAVJ&lt;/div&gt;`)[0];
#                 popup_6314278178ff9218381bb50b60b0d729.setContent(html_b0026b7adda082138cf9e62e4114a2f3);
#
#
#
#         marker_7c36a783770bde499a7cc21e2dbabbb6.bindPopup(popup_6314278178ff9218381bb50b60b0d729)
#         ;
#
#
#
#
#             var marker_9ade767523be778a42038cc23bc0c2e1 = L.marker(
#                 [34.037037, -118.705803],
#                 {
# }
#             ).addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#         var popup_af643df6c09ce5f27bf82e324839084b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb99fa2857f6402a61eca1daa3a78bee = $(`&lt;div id=&quot;html_fb99fa2857f6402a61eca1daa3a78bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 3530-CRZSB&lt;/div&gt;`)[0];
#                 popup_af643df6c09ce5f27bf82e324839084b.setContent(html_fb99fa2857f6402a61eca1daa3a78bee);
#
#
#
#         marker_9ade767523be778a42038cc23bc0c2e1.bindPopup(popup_af643df6c09ce5f27bf82e324839084b)
#         ;
#
#
#
#
#             var marker_07565307269f597372c7b227bfd90895 = L.marker(
#                 [34.037037, -118.705803],
#                 {
# }
#             ).addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#         var popup_8f3703570b5a4042c77ccd7ad7a74e61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d19bcec421ffdc61c3a73cfc69850b3 = $(`&lt;div id=&quot;html_8d19bcec421ffdc61c3a73cfc69850b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 4713-LZDRV&lt;/div&gt;`)[0];
#                 popup_8f3703570b5a4042c77ccd7ad7a74e61.setContent(html_8d19bcec421ffdc61c3a73cfc69850b3);
#
#
#
#         marker_07565307269f597372c7b227bfd90895.bindPopup(popup_8f3703570b5a4042c77ccd7ad7a74e61)
#         ;
#
#
#
#
#             var marker_deae507d2fd1dca27a8604f0ee0c1cd9 = L.marker(
#                 [34.074572, -118.831181],
#                 {
# }
#             ).addTo(map_000023041d23263c6d2d5e3bc38fad39);
#
#
#         var popup_41f1312ff4ef648962f0081aef4c7d82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55ae509e722fe53deb68305de0238a1b = $(`&lt;div id=&quot;html_55ae509e722fe53deb68305de0238a1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 7551-JOHTI&lt;/div&gt;`)[0];
#                 popup_41f1312ff4ef648962f0081aef4c7d82.setContent(html_55ae509e722fe53deb68305de0238a1b);
#
#
#
#         marker_deae507d2fd1dca27a8604f0ee0c1cd9.bindPopup(popup_41f1312ff4ef648962f0081aef4c7d82)
#         ;
#
#
#
#
#             var marker_1b428fe846d21fa1e5c3407ac44c41a8 = L.m

# %%
print(df[df['total_population'] < 100].to_string())
# Out:
#      customer_id                   city  zip_code  total_population   latitude   longitude
# 23    0030-FNXPP                 Keeler     93530                71  36.560498 -117.962461
# 155   0256-LTHVJ                 Ludlow     92338                23  34.702766 -116.093376
# 162   0264-CNITK                   Clio     96106                88  39.745805 -120.580882
# 195   0310-SUCIN                 Darwin     93522                64  36.319181 -117.593053
# 295   0434-CSFON            Los Angeles     90071                21  34.052917 -118.255178
# 330   0487-RPVUM           Mount Hermon     95041                77  37.051166 -122.056194
# 344   0511-JTEOY             Canyon Dam     95923                86  40.171312 -121.120605
# 371   0549-CYCQN               Flournoy     96029                84  39.847840 -122.544556
# 494   0723-VSOBE               Dos Rios     95429                91  39.756049 -123.358701
# 604   0885-HMGPY               Honeydew     95545                82  40.342928 -124.063329
# 607   0887-WBJVH                Cressey     95312                55  37.420273 -120.665270
# 629   0925-VYDLG                 Ludlow     92338                23  34.702766 -116.093376
# 796   1163-ONYEY               Shoshone     92384                87  35.924252 -116.188668
# 915   1334-FJSVR  Sequoia National Park     93262                56  36.527243 -118.594938
# 918   1335-MXCSE               Shoshone     92384                87  35.924252 -116.188668
# 922   1338-CECEE           Mount Hermon     95041                77  37.051166 -122.056194
# 5909  8317-BVKSO                  Termo     96132                72  41.027281 -120.669427
# 6008  8481-YYXWG                   Hume     93628                93  36.807595 -118.901544
# 6026  8519-QJGJD                  Twain     95984                73  40.022184 -121.062384
# 6033  8544-JNBOX                 Weimar     95736                31  39.009780 -120.978273
# 6113  8654-DHAOW                 Burson     95225                27  38.183918 -120.898817
# 6125  8676-OOQEJ                  Amboy     92304                42  34.559882 -115.637164
# 6145  8707-RMEZH                 Tecate     91980                91  32.587557 -116.636816
# 6147  8709-KRDVL              Scott Bar     96085                88  41.737962 -123.075570
# 6190  8755-IWJHN               Honeydew     95545                82  40.342928 -124.063329
# 6205  8777-PVYGU                 Burson     95225                27  38.183918 -120.898817
# 6278  8883-ANODQ                  Termo     96132                72  41.027281 -120.669427
# 6358  8999-EXMNO               Dos Rios     95429                91  39.756049 -123.358701
# 6482  9174-IHETN          Goodyears Bar     95944                76  39.564113 -120.868836
# 6548  9298-WGMRW              Echo Lake     95721                69  38.851842 -120.076204
# 6560  9318-NKNFC                  Twain     95984                73  40.022184 -121.062384
# 6572  9348-ROUAI               Honeydew     95545                82  40.342928 -124.063329
# 6595  9372-TXXPS                 Burson     95225                27  38.183918 -120.898817
# 6605  9389-ACWBI               Richvale     95974                74  39.495768 -121.747472
# 6626  9415-TPKRV               Dos Rios     95429                91  39.756049 -123.358701
# 6661  9477-LGWQI                 Darwin     93522                64  36.319181 -117.593053
# 6720  9546-CQJSU           Soda Springs     95728                88  39.279068 -120.414275
# 6774  9619-GSATL               Dos Rios     95429                91  39.756049 -123.358701
# 6911  9809-IMGCQ             Canyon Dam     95923                86  40.171312 -121.120605
# 6974  9896-UYMIE            Valley Ford     94972                66  38.339996 -122.935056
# 6980  9907-SWKKF                  Twain     95984                73  40.022184 -121.062384
# 6981  9909-DFRJA          Goodyears Bar     95944                76  39.564113 -120.868836
# 6989  9919-YLNNG                 Malibu     90263                11  34.037037 -118.705803
# 7036  9985-MWVIX                   Hume     93628                93  36.807595 -118.901544

# %%
df[df['city'] == 'Twain']
# Out:
#      customer_id   city  zip_code  total_population   latitude   longitude
# 3621  5134-IKDAY  Twain     95984                73  40.022184 -121.062384
# 6026  8519-QJGJD  Twain     95984                73  40.022184 -121.062384
# 6560  9318-NKNFC  Twain     95984                73  40.022184 -121.062384
# 6980  9907-SWKKF  Twain     95984                73  40.022184 -121.062384

# %%
# %pip install folium
import folium

# Crear un mapa centrado en las coordenadas de California
mapa = folium.Map(location=[37.2502200, -119.7512600], zoom_start=5)

# Añadir marcadores para los registros problemáticos
for _, row in df[df['total_population'] < 50].iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=f"Customer ID: {row['customer_id']}").add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a78e09c72d5e99ea25d2d6a9a57557e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a78e09c72d5e99ea25d2d6a9a57557e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a78e09c72d5e99ea25d2d6a9a57557e9 = L.map(
#                 &quot;map_a78e09c72d5e99ea25d2d6a9a57557e9&quot;,
#                 {
#                     center: [37.25022, -119.75126],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_536b6238e7bd892d6c73dd2d86bb265d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_536b6238e7bd892d6c73dd2d86bb265d.addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#             var marker_4ae14367e7b8200b67dc465a1a3accf2 = L.marker(
#                 [34.702766, -116.093376],
#                 {
# }
#             ).addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#         var popup_63b0660233cc5ded43cf77d0646bd648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e68cddda25e648577c63dddda9328e9a = $(`&lt;div id=&quot;html_e68cddda25e648577c63dddda9328e9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 0256-LTHVJ&lt;/div&gt;`)[0];
#                 popup_63b0660233cc5ded43cf77d0646bd648.setContent(html_e68cddda25e648577c63dddda9328e9a);
#
#
#
#         marker_4ae14367e7b8200b67dc465a1a3accf2.bindPopup(popup_63b0660233cc5ded43cf77d0646bd648)
#         ;
#
#
#
#
#             var marker_21731043943d9057a3b53e5403c50eb2 = L.marker(
#                 [34.052917, -118.255178],
#                 {
# }
#             ).addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#         var popup_bc6edc7e865ccf8b4a3d63a922617798 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f07de92d53fa40f848ebf98785639d27 = $(`&lt;div id=&quot;html_f07de92d53fa40f848ebf98785639d27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 0434-CSFON&lt;/div&gt;`)[0];
#                 popup_bc6edc7e865ccf8b4a3d63a922617798.setContent(html_f07de92d53fa40f848ebf98785639d27);
#
#
#
#         marker_21731043943d9057a3b53e5403c50eb2.bindPopup(popup_bc6edc7e865ccf8b4a3d63a922617798)
#         ;
#
#
#
#
#             var marker_8b836ecbc529f70757e3031c57fe8609 = L.marker(
#                 [34.702766, -116.093376],
#                 {
# }
#             ).addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#         var popup_2e09bc3744c61ace19407316711f96c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ac9f71dbf45c92e4ab1645bbf92abb1 = $(`&lt;div id=&quot;html_8ac9f71dbf45c92e4ab1645bbf92abb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 0925-VYDLG&lt;/div&gt;`)[0];
#                 popup_2e09bc3744c61ace19407316711f96c1.setContent(html_8ac9f71dbf45c92e4ab1645bbf92abb1);
#
#
#
#         marker_8b836ecbc529f70757e3031c57fe8609.bindPopup(popup_2e09bc3744c61ace19407316711f96c1)
#         ;
#
#
#
#
#             var marker_887f98283f61a0fac6243ae8cded0c90 = L.marker(
#                 [38.805481, -120.13287],
#                 {
# }
#             ).addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#         var popup_cf0c2fe4891d684481972c3594a80d0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a69d602e73519b6738117f4355fe2e72 = $(`&lt;div id=&quot;html_a69d602e73519b6738117f4355fe2e72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 1666-JZPZT&lt;/div&gt;`)[0];
#                 popup_cf0c2fe4891d684481972c3594a80d0c.setContent(html_a69d602e73519b6738117f4355fe2e72);
#
#
#
#         marker_887f98283f61a0fac6243ae8cded0c90.bindPopup(popup_cf0c2fe4891d684481972c3594a80d0c)
#         ;
#
#
#
#
#             var marker_17cee0d272bd00f3ab91fde956d8838d = L.marker(
#                 [34.037037, -118.705803],
#                 {
# }
#             ).addTo(map_a78e09c72d5e99ea25d2d6a9a57557e9);
#
#
#         var popup_83794eeb4995dbbb21ade1b226972f25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5689cef29f9e5395b23c9faacd4cd51 = $(`&lt;div id=&quot;html_c5689cef29f9e5395b23c9faacd4cd51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Customer ID: 2040-XBAVJ&lt;/div&gt;`)[0];
#                 popup_83794eeb4995dbbb21ade1b226972f25.setContent(html_c5689cef29f9e5395b23c9faacd4cd51);
#
#
#
#         marker_17cee0d272bd00f3ab91fde956d8838d.bindPopup(popup_83794eeb4995dbbb21ade1b226972f25)
#         ;
#
#
#
#
#             var marker_c91b423f2cac93fffb7801ae54f14ea0 = L.marke

# %%
df['zip_code'] = df['zip_code'].astype(str)

resultado = df.groupby('zip_code')['total_population'].agg(min_population='min', max_population='max')

resultado
# Out:
#           min_population  max_population
# zip_code
# 90001              54492           54492
# 90002              44586           44586
# 90003              58198           58198
# 90004              67852           67852
# 90005              43019           43019
# ...                  ...             ...
# 96143               4806            4806
# 96145               4002            4002
# 96146                942             942
# 96148                678             678
# 96150              33038           33038
#
# [1625 rows x 2 columns]

# %%
resultado[resultado['min_population'] != resultado['max_population']]
# Out:
# Empty DataFrame
# Columns: [min_population, max_population]
# Index: []

# %% [markdown]
# - Luego de analizar nuestro dataset nos encontramos que el código postal 90263 Malibu, CA contaba con una población estimada de 11 habitantes lo que genera dudas a simple vista y fuimos encontrando otras áreas también de rangos menores en cuanto a nivel poblacional. Al agrupar estos por el codigo postal nos dimos cuenta que tanto el mínimo registrado como el máximo era el mismo, lo que indicaría que el área a tratar no es de gran nivel territorial. Aún así viendo fuentes de datos como la página oficial de los Estados Unidos nos damos cuenta que ese valor no es del todo correcto y que dependerá luego si quisiseramos un análisis de mayor índole la modificación de estos.

# %% [markdown]
# ### Análisis exploratorio basado en el status del cliente.

# %%
df1 = pd.read_csv(r"..\data\clean\status_analysis_clean.csv")
df2 = pd.merge(left = df, right =df1, on ="customer_id")

# %%
df2.head()
# Out:
#   customer_id          city zip_code  total_population   latitude   longitude  \
# 0  0002-ORFBO  Frazier Park    93225              4498  34.827662 -118.999073
# 1  0003-MKNFE      Glendale    91206             31297  34.162515 -118.203869
# 2  0004-TLHLJ    Costa Mesa    92627             62069  33.645672 -117.922613
# 3  0011-IGKFF      Martinez    94553             46677  38.014457 -122.115432
# 4  0013-EXCHZ     Camarillo    93010             42853  34.227846 -119.079903
#
#    satisfaction_score  cltv customer_status churn_label   churn_category  \
# 0                   3  2205          Stayed          No   Not Applicable
# 1                   5  5414          Stayed          No   Not Applicable
# 2                   1  4479         Churned         Yes       Competitor
# 3                   1  3714         Churned         Yes  Dissatisfaction
# 4                   1  3464         Churned         Yes  Dissatisfaction
#
#   churn_group                 razon_abandono
# 0    [60, 70)  Competitor had better devices
# 1    [60, 70)  Competitor had better devices
# 2    [70, 80)  Competitor had better devices
# 3   [90, 100)        Product dissatisfaction
# 4    [60, 70)            Network reliability

# %% [markdown]
# ---
#
# ### **1️⃣. Hipótesis sobre la Ubicación Geográfica y Churn**
# - **Hipótesis:** Existen diferencias en la tasa de abandono de clientes según la **latitud y longitud**, lo que podría indicar patrones regionales en el churn.
#
# ---

# %%
from scipy.stats import spearmanr

df2['churn_label'] = df2['churn_label'].map({'No': 0, 'Yes': 1})

# Calcular la correlación de Spearman entre churn y coordenadas geográficas
corr_lat, p_lat = spearmanr(df2['churn_label'], df2['latitude'])
corr_lon, p_lon = spearmanr(df2['churn_label'], df2['longitude'])

print(f"Correlación entre churn y latitud: {corr_lat}, p-valor: {p_lat}")
print(f"Correlación entre churn y longitud: {corr_lon}, p-valor: {p_lon}")

# Evaluar significancia estadística
alpha = 0.05
if p_lat < alpha:
    print("La latitud tiene una relación significativa con churn.")
else:
    print("No hay suficiente evidencia para concluir que la latitud influye en churn.")

if p_lon < alpha:
    print("La longitud tiene una relación significativa con churn.")
else:
    print("No hay suficiente evidencia para concluir que la longitud influye en churn.")
# Out:
# Correlación entre churn y latitud: -0.046323736378060504, p-valor: 0.00010065593260520903
# Correlación entre churn y longitud: 0.030386848883353405, p-valor: 0.010763671400496909
# La latitud tiene una relación significativa con churn.
# La longitud tiene una relación significativa con churn.

# %%
plt.figure(figsize=(12, 7))

# Crear scatterplot de churn
scatter = sns.scatterplot(
    data=df2, x='longitude', y='latitude', hue='churn_label',
    palette={0: 'blue', 1: 'red'}, alpha=0.5
)

# Obtener los 5 estados con más churn
top_states = df2[df2['churn_label'] == 1]['city'].value_counts().head(5).index

# Agregar etiquetas solo en el centro de los puntos de cada estado
for state in top_states:
    state_data = df2[df2['city'] == state]
    plt.text(state_data['longitude'].mean(),  # Promedio de longitud
             state_data['latitude'].mean(),   # Promedio de latitud
             state, fontsize=12, fontweight='bold', color='black', alpha=0.9)

plt.title("Distribución Geográfica de Clientes según Churn (Top 5 Estados)")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.legend(title="Churn (1 = Abandonó, 0 = No Abandonó)")
plt.show()

# %%
churn = df2[df2['churn_label'] == 1].groupby('churn_label')['city'].value_counts()
df_churn = pd.DataFrame(churn)
df_churn[df_churn['count'] > 20]
# Out:
#                            count
# churn_label city
# 1           San Diego        185
#             Los Angeles       78
#             San Francisco     31
#             San Jose          29
#             Fallbrook         26
#             Sacramento        26
#             Temecula          22

# %%
# Cantidad total de clientes que abandonaron el servicio 
df2[df2['churn_label'] == 1].value_counts().size
# Out:
# 1869

# %% [markdown]
# ✅ **Conclusión:**
# El análisis muestra que la latitud y la longitud tienen una relación significativa con la tasa de abandono de clientes, aunque el grado de correlación es bajo. Esto sugiere que ciertos factores geográficos pueden influir en la cancelación del servicio, como diferencias en la calidad de la cobertura, competencia en determinadas regiones o variaciones en el poder adquisitivo de los clientes. Identificar estas tendencias puede ayudar a la empresa a desarrollar estrategias localizadas para reducir el churn, como mejoras en la infraestructura o campañas de retención específicas según la ubicación.
